# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)                                                    | Output     |
# | ---- | -----------                                                 | ---------  |
# | 1.1  | Another car ahead slowing down                              | Self driving car recognises brake lights and reducing distance and applies the brakes|
# | 1.2  | Users watch time on horror movies is highest of all data    | Recommend more horror movies they havent watched|
# | 1.3  | Image captured of two signatures 1 real 1 unknown, to verify unknown| Verify if the signature matches the sample yes or no match
# | 1.4  | User enters symptoms of illness                        | Previous symptoms matched with illness, diagnosis offered and recommendation for treatment|

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 Classification, as there can be labeled examples of socail and promotional emails that can be supplied to help the program learn the difference
# * 2.2 Regression, there are no set examples for good or bad stocks therefore using regression on the historical data and market trends can help recognise patterns and make predictions
# * 2.3 Classification, as the program can learn from distinguishing features on the animals that define their species and subspecies
# * 2.4 Classification, using the samples from the historic data and the diagnostic test, it will tell is if it matches or not

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 Un-supervised, as there is no prior knowledge, no examples can be given to guide the programs learning of anomalies
# * 3.2 Supervised, as we can use values and patterns in the date to improve the accuracy of the programs predictions
# * 3.3 Supervised, the data is there and samples can be fed into the program to match the correct customers to demographics
# * 3.4 Supervised, because a set of posts with defining features for catagories can be fed into the program to match data

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 Appropriate use, will work here because you can give the algoritm vital information on previous fraudulent transactions and find new data from the unlabelled data, this could unearth fraudulent transactions deemed legitimate or find data not previously labled or specified
# * 4.2 Appropriate use, as a small portian of data is labelled so giving input to the program will help identify certain catagories
# * 4.3 inappropriate use, plenty of examples of spam emails labeled to give for sample so full supvervised leaning will be fine
# * 4.4 inappropriate use, unsupervised learning would work best as not specified with any labeled information so letting the program define catagories would be best to determine a pattern
